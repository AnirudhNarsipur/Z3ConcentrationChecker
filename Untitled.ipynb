# %%
import json

# %%
fl = "/Users/anirudh/Projects/CSAdvise/examples/sample_declarations/true.json"

# %%
df = json.load(open(fl))

# %%
df["plan_items"]
# Out:
# [{'display_name': 'Zachary T Espiritu',
#   'banner_id': 'B01117716',
#   'email': 'zachary_espiritu@brown.edu',
#   'advisor_name': 'Tim Nelson',
#   'advisor_email': 'timothy_nelson@brown.edu',
#   'declaration_uuid': '1fa4fdb3-1320-05c4-3923-800a60e3e4bd',
#   'degree_short': 'Sc.B.',
#   'conc_code': 'COMP',
#   'track_code': None,
#   'term_id': '201820',
#   'requirement_uuid': 'ca5c8172-5e40-49e6-b2da-75e6290a3f34',
#   'is_substitution': '0',
#   'subject_code': 'MATH',
#   'course_number': '0100'},
#  {'display_name': 'Zachary T Espiritu',
#   'banner_id': 'B01117716',
#   'email': 'zachary_espiritu@brown.edu',
#   'advisor_name': 'Tim Nelson',
#   'advisor_email': 'timothy_nelson@brown.edu',
#   'declaration_uuid': '1fa4fdb3-1320-05c4-3923-800a60e3e4bd',
#   'degree_short': 'Sc.B.',
#   'conc_code': 'COMP',
#   'track_code': None,
#   'term_id': '201820',
#   'requirement_uuid': 'a5bacb4f-7d95-47c7-8970-3777cf41420c',
#   'is_substitution': '0',
#   'subject_code': 'CSCI',
# ...
